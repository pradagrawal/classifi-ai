# %% [markdown]
# # 🎧 WhisperX Transcription Demo
# This notebook demonstrates audio transcription using WhisperX with diarization.

# %%
# !pip install -r https://raw.githubusercontent.com/pradagrawal/classifi-ai/main/requirements.txt

# %%
# !pip install git+https://github.com/m-bain/whisperx.git
# !pip install ffmpeg-python

# %%
import whisperx
model = whisperx.load_model("large-v2", device="cuda")
audio_file = "/content/sample_audio.mp3"  # Replace with your audio path
transcription = model.transcribe(audio_file)
transcription['segments'][:3]  # Preview first 3 segments
